# %% [markdown]
# # Verification of Quality Check
#
# <!-- - @author: [Hamid Ali Syed](https://syedha.com)
#  -->
# - Date: Jan 21, 2023

# %% [markdown]
# ## Packages:
# - pydda is for Dual/Multi-Doppler Analysis
# - pyart is for reading and plotting radar data
# - wradlib is also a radar toolkit like pyart, and it supports `xarray.dataset` type
# - Xarray makes working with labelled `multi-dimensional` arrays in Python simple, efficient, and fun!
# - Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool for working with `tabular` data
# - cartopy is used to plot `maps`, `projections` and much more.

# %%
import warnings
warnings.filterwarnings("ignore")
import pyart
# import pydda
import wradlib as wrl
import xarray as xr
import xradar as xd
import datatree as xt
# import pandas as pd
# import datetime as dt
import numpy as np
# import scipy
# import wradlib as wrl
# import netCDF4 as nc
from matplotlib import pyplot as plt
from matplotlib.ticker import NullFormatter, FuncFormatter
from matplotlib import axes
import cartopy.crs as ccrs
import cartopy.feature as feat
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import glob, os, sys, re
# %matplotlib inline
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead

# %%
def add_map(ax, b = 0, l = 0):
    gl = ax.gridlines(crs=ccrs.PlateCarree(), linewidth=0.3, color='black', alpha=0.3, 
                         linestyle='-', draw_labels=True)
    gl.xlabels_top = False
    gl.xlabels_bottom = b
    gl.ylabels_left = l
    gl.ylabels_right= False
    gl.xlines = True
    gl.ylines = True
    gl.xformatter = LONGITUDE_FORMATTER
    gl.yformatter = LATITUDE_FORMATTER
    ax.add_feature(feat.BORDERS, lw = 0.5)
#     ax.add_feature(feat.LAND, lw = 0.3, fc = [0.9,0.9,0.9])
    ax.add_feature(feat.COASTLINE, lw = 0.5)
#     ax.add_feature(feat.OCEAN, alpha = 0.5)
    ax.add_feature(feat.STATES.with_scale("10m"), alpha = 0.5, lw = 0.5, ls = "--")

# %%
basedir = "/depot/dawson29/data/Projects/PERiLS/obsdata/2022/Illinois_Mobile_Radar/IOP1/"
radar_type = ["COW1", "DOW7", "DOW8"]
data_folder = "QCed"

# %%
cow1_files = glob.glob(f"{basedir}{radar_type[0]}{os.sep}{data_folder}{os.sep}*.nc")

# %%
savedir = f"{basedir}{'plots'}{os.sep}"

# %%
for cfile in cow1_files[100:101]:
    ds = xr.open_dataset(cfile, engine="netcdf4")

# %%
sweeps = xd.io.backends.cfradial1._get_sweep_groups(
    ds, optional=False, site_coords=True, first_dim="time"
)
with xr.set_options(display_expand_data_vars=True):
    display(sweeps["sweep_0"])
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 720, range: 1180)
# Coordinates:
#   * time               (time) datetime64[ns] 2022-03-22T23:01:45.249000072 .....
#   * range              (range) float32 87.5 162.4 237.4 ... 8.837e+04 8.844e+04
#     azimuth            (time) float32 33.3 33.8 34.3 34.8 ... 31.8 32.3 32.8
#     elevation          (time) float32 4.432 4.377 4.322 ... 0.7843 0.8172 0.8502
#     latitude           (time) float64 ...
#     longitude          (time) float64 ...
#     altitude           (time) float64 ...
# Data variables: (12/22)
#     NCP                (time, range) float32 ...
#     TRIP_FLA           (time, range) float32 ...
#     SNRHC              (time, range) float32 ...
#     SNRVC              (time, range) float32 ...
#     DBZHC              (time, range) float32 ...
#     DBZHC_F            (time, range) float32 ...
#     ...                 ...
#     DBZH               (time, range) float32 ...
#     sweep_number       float64 ...
#     sweep_fixed_angle  float32 ...
#     sweep_mode         |S32 ...
#     follow_mode        |S32 ...
#     prt_mode           |S32 ...

# %%
sweeps['sweep_0']['longitude'] = sweeps['sweep_0'].longitude[0]
sweeps['sweep_0']['latitude'] = sweeps['sweep_0'].latitude[0]
sweeps['sweep_0']['altitude'] = sweeps['sweep_0'].altitude[0]

# %%
sweeps['sweep_0'].pipe(wrl.georef.georeference_dataset)
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 720, range: 1180)
# Coordinates: (12/13)
#   * time               (time) datetime64[ns] 2022-03-22T23:01:45.249000072 .....
#   * range              (range) float32 87.5 162.4 237.4 ... 8.837e+04 8.844e+04
#     azimuth            (time) float32 33.3 33.8 34.3 34.8 ... 31.8 32.3 32.8
#     elevation          (time) float32 4.432 4.377 4.322 ... 0.7843 0.8172 0.8502
#     latitude           float64 32.81
#     longitude          float64 -87.95
#     ...                 ...
#     x                  (time, range) float32 47.9 88.92 ... 4.786e+04 4.79e+04
#     y                  (time, range) float32 72.91 135.4 ... 7.426e+04 7.432e+04
#     z                  (time, range) float32 65.0 70.0 ... 1.829e+03 1.83e+03
#     gr                 (time, range) float32 87.24 162.0 ... 8.834e+04 8.842e+04
#     rays               (time, range) float32 4.432 4.432 4.432 ... 0.8502 0.8502
#     bins               (time, range) float32 87.5 162.4 ... 8.837e+04 8.844e+04
# Data variables: (12/22)
#     NCP                (time, range) float32 ...
#     TRIP_FLA           (time, range) float32 ...
#     SNRHC              (time, range) float32 ...
#     SNRVC              (time, range) float32 ...
#     DBZHC              (time, range) float32 ...
#     DBZHC_F            (time, range) float32 ...
#     ...                 ...
#     DBZH               (time, range) float32 ...
#     sweep_number       float64 ...
#     sweep_fixed_angle  float32 ...
#     sweep_mode         |S32 b'azimuth_surveillance'
#     follow_mode        |S32 ...
#     prt_mode           |S32 ...

# %%
vol

# %%
for cfile in cow1_files:
    ds = 
    display = pyart.graph.RadarMapDisplay(radar)
    fig = plt.figure(figsize=(12, 10), constrained_layout = True)
    ax = plt.subplot(221)
    display.plot_ppi('DBZH', 0, vmin=-10., vmax = 60, cmap = 'pyart_HomeyerRainbow')
    ax = plt.subplot(222)
    display.plot_ppi('VEL_F', 0, vmin=-30., vmax = 30, cmap = 'pyart_NWSVel')
    ax = plt.subplot(223)
    display.plot_ppi('ZDRC', 0, vmin = -7.9, vmax = 7.9, cmap = pyart.graph.cm.RefDiff)
    ax = plt.subplot(224)
    display.plot_ppi('PHIDP', 0, vmin = -179, vmax = 179, cmap = pyart.graph.cm.RefDiff)
    filenames = os.path.join(savedir, cfile.split(os.sep)[-1].split('_to_')[-1].split('.nc')[0] + '.png')
    plt.savefig(filenames, bbox_inches = "tight")
    plt.close()
    del radar
    del display

# %%
from PIL import Image
imgs = glob.glob(os.path.join(savedir, '*.png'))
# sorting the files by time
imgs.sort()

images = []
for file_name in imgs:
    images.append(Image.open(file_name))

images[0].save(os.path.join(savedir,'animation_iop1_cow1.gif'), 
               save_all=True, 
               append_images=images[1:], 
               duration=50*1000/len(images), loop=0)

# %% [markdown]
# from IPython.display import display
# from IPython.display import Image
#
# image1 = Image(filename=os.path.join(savedir,'animation_iop1_cow1.gif'), retina=True)
# image2 = Image(filename=os.path.join(savedir,"uf",'uf_iop1_cow1_animation.gif'), retina=True)
#
# display(image1, image2)

# %%
uf_files = glob.glob(os.path.join(basedir, radar_type[0], "merged/*nc"))
len(uf_files)
# Out:
# 181

# %%
for cfile in uf_files:
    ds = 
    display = pyart.graph.RadarMapDisplay(radar)
    fig = plt.figure(figsize=(12, 10), constrained_layout = True)
    ax = plt.subplot(221)
    display.plot_ppi('DBZHCC_F', 0, vmin=-10., vmax = 60, cmap = 'pyart_HomeyerRainbow')
    ax = plt.subplot(222)
    display.plot_ppi('VEL_F', 0, vmin=-30., vmax = 30, cmap = 'pyart_NWSVel')
    ax = plt.subplot(223)
    display.plot_ppi('ZDRC', 0, vmin = -7.9, vmax = 7.9, cmap = pyart.graph.cm.RefDiff)
    ax = plt.subplot(224)
    display.plot_ppi('PHIDP', 0, vmin = -179, vmax = 179, cmap = pyart.graph.cm.RefDiff)
    filenames = os.path.join(savedir, cfile.split(os.sep)[-1].split('_to_')[-1].split('.nc')[0] + '.png')
    plt.savefig(filenames, bbox_inches = "tight")
    plt.close()
    del radar
    del display

# %%
os.path.join(savedir,'animation_iop1_cow1.gif')
# Out:
# '/depot/dawson29/data/Projects/PERiLS/obsdata/2022/Illinois_Mobile_Radar/IOP1/plots/animation_iop1_cow1.gif'

# %%
def filter_radar(radar, vel_field="VEL_F", refl_field="DBZHCC_F", 
                 ncp_field="NCP", rhv_field="RHOHV", phi_field="PHIDP"):
    '''Remove noise based on velocity texture and mask all the fields'''
    # Drop some fields
    fields_to_drop = ["DBMHC", "DBMVC", "VEL", "VS", "VS_F", "VL", "VL_F", "DBZHCC"]
    for field in fields_to_drop:
        if field in radar.fields:
            del radar.fields[field]
        
    texture = pyart.retrieve.calculate_velocity_texture(radar, 
                                                        vel_field=vel_field, 
                                                        wind_size=5, 
                                                        check_nyq_uniform=False)
    radar.add_field('VT',texture,replace_existing=True)
    # create gatefilter
    gf = pyart.filters.GateFilter(radar)
    gf.exclude_invalid(refl_field)
    gf.exclude_outside(refl_field, -20, 90)
    gf.exclude_below("SNRHC", 10)
    gf.exclude_above('VT', 9) # Value found by trial and error for this case
    gf_despeckeld = pyart.correct.despeckle_field(radar, refl_field, gatefilter=gf)
    corr_ZH = radar.fields[refl_field].copy()
    ZH_array = np.ma.masked_where(gf_despeckeld.gate_included == False, radar.fields[refl_field]['data'])
    corr_ZH['data'] = ZH_array
    radar.add_field('DBZH',corr_ZH,replace_existing=True)
    
    # get the mask
    mask = np.ma.getmask(radar.fields['DBZH']['data'])

    # iterate through remaining fields
    for field in radar.fields.keys():
        # mask the field
        radar.fields[field]['data'] = np.ma.masked_where(mask, radar.fields[field]['data'])
    return radar

# %%
def dealiase(radar, vel_name):
    #check to see if radar object has nyquist velocity
    try: 
        gatefilter = pyart.correct.GateFilter(radar)
        corr_vel   = pyart.correct.dealias_region_based(
            radar, vel_field=vel_name, keep_original=False, gatefilter = gatefilter)
        radar.add_field(vel_name, corr_vel, True)
    except:
        None

# %%
def natural_sort_key(s, _re=re.compile(r'(\d+)')):
    return [int(t) if i & 1 else t.lower() for i, t in enumerate(_re.split(s))]

# %%
basedir = "/depot/dawson29/data/Projects/PERiLS/obsdata/2022/Illinois_Mobile_Radar/"
iop1 = os.path.join(basedir,"IOP1")

# %%
cow1 = os.path.join(iop1, "COW1/merged/")
dow7 = os.path.join(iop1, "DOW7/merged/")
dow8 = os.path.join(iop1, "DOW8/merged/")

# %%
cow1_files = sorted(glob.glob(os.path.join(cow1,"*nc")), key=natural_sort_key)
print(f'No. of COW1 files: {len(cow1_files)}')
dow7_files = sorted(glob.glob(os.path.join(dow7,"*nc")), key=natural_sort_key)
print(f'No. of DOW7 files: {len(dow7_files)}')
dow8_files = sorted(glob.glob(os.path.join(dow8,"*nc")), key=natural_sort_key)
print(f'No. of DOW8 files: {len(dow8_files)}')

# %%
out_dir = "/depot/dawson29/data/Projects/PERiLS/obsdata/2022/Illinois_Mobile_Radar/IOP1/"
radar_type = ["COW1", "DOW7", "DOW8"]

# %%
import matplotlib.pyplot as plt
from metpy.plots import SkewT
from metpy.calc import potential_temperature

# Initial conditions
temp = 10  # oC
dewpt = 0  # oC
pressure = 850  # mb

# Create the Skew-T plot
fig = plt.figure(figsize=(9, 9))
skew = SkewT(fig, rotation=45)

# Plot the location of the temperature and dewpoint with red and green dots, respectively
skew.plot(pressure, temp, 'ro', label='Temperature')
skew.plot(pressure, dewpt, 'go', label='Dewpoint')

# Annotate the potential temperature of the parcel in blue
pot_temp = potential_temperature(pressure, temp)
skew.plot(pressure, pot_temp, 'bo', label='Potential Temperature')

# Draw the path of the parcel's temperature and dewpoint as it is lifted dry adiabatically to saturation
skew.plot_dry_adiabats()
skew.plot_moist_adiabats()
lcl_pressure, lcl_temp = skew.lift(pressure, temp, dewpt)
skew.plot(lcl_pressure, lcl_temp, 'ko', label='LCL')

# Draw the path of the parcel's temperature as it is lifted moist adiabatically to a pressure of 300 mb
temp_300mb, _ = skew.find_intersection(skew.moist_adiabats, 300)
skew.plot(300, temp_300mb, 'ko')

# Annotate the parcel's temperature and dewpoint at this level
temp_dewpt_300mb = skew.dewpoint_from_mixing_ratio(skew.mixing_ratio_from_pressure_and_dewpt(300, dewpt))
skew.plot(300, temp_dewpt_300mb, 'ko')

# Add labels and legend
skew.plot_mixing_lines()
skew.ax.set_ylim(-100, 100)
skew.ax.set_xlim(1000, 100)
skew.ax.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 from metpy.plots import SkewT
#       3 from metpy.calc import potential_temperature
#       5 # Initial conditions
#
# ModuleNotFoundError: No module named 'metpy'

# %%
# !conda install -c conda-forge metpy --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/linux-64::anaconda==2021.11=py39_0
#   - defaults/linux-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39h06a4308_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /apps/cent7/jupyterhub
#
#   added / updated specs:
#     - metpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.10  |           py39_2          67 KB
#     anaconda-custom            |           py39_1           3 KB
#     automat-22.10.0            |     pyhd8ed1ab_0          27 KB  conda-forge
#     bcrypt-3.2.2               |   py39hb9d737c_1          45 KB  conda-forge
#     boto3-1.26.55              |     pyhd8ed1ab_0          75 KB  conda-forge
#     botocore-1.29.55           |     pyhd8ed1ab_0         5.7 MB  conda-forge
#     cartopy-0.21.1             |   py39h6e7ad6e_0         1.5 MB  conda-forge
#     colorcet-3.0.1             |     pyhd8ed1ab_0         1.6 MB  conda-forge
#     conda-4.14.0               |   py39hf3d152e_0        1011 KB  conda-forge
#     constantly-15.1.0          |             py_0           9 KB  conda-forge
#     cssselect-1.2.0            |     pyhd8ed1ab_0          21 KB  conda-forge
#     datashader-0.14.3          |     pyh1a96a4e_0        16.3 MB  conda-forge
#     gensim-4.3.0               |   py39h2ad29b5_1        21.8 MB  conda-forge
#     holoviews-1.15.4           |     pyhd8ed1ab_0         3.2 MB  conda-forge
#     hvplot-0.8.2               |     pyhd8ed1ab_0         3.0 MB  conda-forge
#     hyperlink-21.0.0           |     pyhd3deb0d_0          71 KB  conda-forge
#     incremental-22.10.0        |     pyhd8ed1ab_0          18 KB  conda-forge
#     intake-0.6.6               |     pyhd8ed1ab_0         114 KB  conda-forge
#     itemadapter-0.7.0          |     pyhd8ed1ab_0          14 KB  conda-forge
#     itemloaders-1.0.6          |     pyhd8ed1ab_0          14 KB  conda-forge
#     jq-1.6                     |    h36c2ea0_1000         346 KB  conda-forge
#     jupyter_server-1.13.5      |     pyhd3eb1b0_0         259 KB
#     libidn2-2.3.4              |       h166bdaf_0         157 KB  conda-forge
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     metpy-1.4.0                |     pyhd8ed1ab_0         316 KB  conda-forge
#     nbclassic-0.3.7            |     pyhd8ed1ab_0          14 KB  conda-forge
#     oniguruma-6.9.8            |       h166bdaf_0         430 KB  conda-forge
#     panel-0.14.2               |     pyhd8ed1ab_0        11.8 MB  conda-forge
#     param-1.12.3               |     pyh1a96a4e_0          78 KB  conda-forge
#     parsel-1.7.0               |     pyhd8ed1ab_0          17 KB  conda-forge
#     pint-0.20.1                |     pyhd8ed1ab_0         207 KB  conda-forge
#     plotly-5.13.0              |     pyhd8ed1ab_0         4.2 MB  conda-forge
#     proj-8.0.1                 |       h277dcde_0         3.1 MB  conda-forge
#     protego-0.2.1              |     pyhd8ed1ab_0         2.6 MB  conda-forge
#     pydispatcher-2.0.5         |             py_1          12 KB  conda-forge
#     pyhamcrest-2.0.4           |     pyhd8ed1ab_0          44 KB  conda-forge
#     pyproj-3.3.1               |   py39h02a9fcc_1         482 KB  conda-forge
#     pyviz_comms-2.2.1          |     pyhd8ed1ab_1          31 KB  conda-forge
#     queuelib-1.6.2             |     pyhd8ed1ab_0          14 KB  conda-forge
#     requests-file-1.5.1        |     pyh9f0ad1d_0           7 KB  conda-forge
#     scrapy-2.7.1               |   py39hf3d152e_0         825 KB  conda-forge
#     service_identity-18.1.0    |             py_0          12 KB  conda-forge
#     shapely-2.0.0              |   py39hc9151fd_0         410 KB  conda-forge
#     smart_open-6.3.0           |     pyhd8ed1ab_1          46 KB  conda-forge
#     tabulate-0.9.0             |     pyhd8ed1ab_1          35 KB  conda-forge
#     tenacity-8.1.0             |     pyhd8ed1ab_0          21 KB  conda-forge
#     tldextract-3.4.0           |     pyhd8ed1ab_0          93 KB  conda-forge
#     twisted-22.2.0             |   py39h5eee18b_1         4.1 MB
#     w3lib-2.1.1                |     pyhd8ed1ab_0          24 KB  conda-forge
#     wget-1.20.3                |       ha56f1ee_1         804 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        86.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/linux-64::_anaconda_depends-2022.10-py39_2
#   anyio              conda-forge/noarch::anyio-3.6.2-pyhd8ed1ab_0
#   automat            conda-forge/noarch::automat-22.10.0-pyhd8ed1ab_0
#   bcrypt             conda-forge/linux-64::bcrypt-3.2.2-py39hb9d737c_1
#   boto3              conda-forge/noarch::boto3-1.26.55-pyhd8ed1ab_0
#   botocore           conda-forge/noarch::botocore-1.29.55-pyhd8ed1ab_0
#   cartopy            conda-forge/linux-64::cartopy-0.21.1-py39h6e7ad6e_0
#   colorcet           conda-forge/noarch::colorcet-3.0.1-pyhd8ed1ab_0
#   constantly         conda-forge/noarch::constantly-15.1.0-py_0
#   cssselect          conda-forge/noarch::cssselect-1.2.0-pyhd8ed1ab_0
#   datashader         conda-forge/noarch::datashader-0.14.3-pyh1a96a4e_0
#   datashape          conda-forge/noarch::datashape-0.5.4-py_1
#   gensim             conda-forge/linux-64::gensim-4.3.0-py39h2ad29b5_1
#   geos               conda-forge/linux-64::geos-3.11.1-h27087fc_0
#   gettext            conda-forge/linux-64::gettext-0.21.1-h27087fc_0
#   holoviews          conda-forge/noarch::holoviews-1.15.4-pyhd8ed1ab_0
#   hvplot             conda-forge/noarch::hvplot-0.8.2-pyhd8ed1ab_0
#   hyperlink          conda-forge/noarch::hyperlink-21.0.0-pyhd3deb0d_0
#   incremental        conda-forge/noarch::incremental-22.10.0-pyhd8ed1ab_0
#   intake             conda-forge/noarch::intake-0.6.6-pyhd8ed1ab_0
#   itemadapter        conda-forge/noarch::itemadapter-0.7.0-pyhd8ed1ab_0
#   itemloaders        conda-forge/noarch::itemloaders-1.0.6-pyhd8ed1ab_0
#   jmespath           conda-forge/noarch::jmespath-1.0.1-pyhd8ed1ab_0
#   jq                 conda-forge/linux-64::jq-1.6-h36c2ea0_1000
#   jupyter_server     pkgs/main/noarch::jupyter_server-1.13.5-pyhd3eb1b0_0
#   libidn2            conda-forge/linux-64::libidn2-2.3.4-h166bdaf_0
#   libunistring       conda-forge/linux-64::libunistring-0.9.10-h7f98852_0
#   markdown           conda-forge/noarch::markdown-3.4.1-pyhd8ed1ab_0
#   metpy              conda-forge/noarch::metpy-1.4.0-pyhd8ed1ab_0
#   nbclassic          conda-forge/noarch::nbclassic-0.3.7-pyhd8ed1ab_0
#   notebook-shim      conda-forge/noarch::notebook-shim-0.2.2-pyhd8ed1ab_0
#   oniguruma          conda-forge/linux-64::oniguruma-6.9.8-h166bdaf_0
#   panel              conda-forge/noarch::panel-0.14.2-pyhd8ed1ab_0
#   param              conda-forge/noarch::param-1.12.3-pyh1a96a4e_0
#   parsel             conda-forge/noarch::parsel-1.7.0-pyhd8ed1ab_0
#   pint               conda-forge/noarch::pint-0.20.1-pyhd8ed1ab_0
#   plotly             conda-forge/noarch::plotly-5.13.0-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.6.0-pyhd8ed1ab_0
#   proj               conda-forge/linux-64::proj-8.0.1-h277dcde_0
#   protego            conda-forge/noarch::protego-0.2.1-pyhd8ed1ab_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   pyct               conda-forge/noarch::pyct-0.4.6-py_0
#   pyct-core          conda-forge/noarch::pyct-core-0.4.6-py_0
#   pydispatcher       conda-forge/noarch::pydispatcher-2.0.5-py_1
#   pyhamcrest         conda-forge/noarch::pyhamcrest-2.0.4-pyhd8ed1ab_0
#   pyproj             conda-forge/linux-64::pyproj-3.3.1-py39h02a9fcc_1
#   pyshp              conda-forge/noarch::pyshp-2.3.1-pyhd8ed1ab_0
#   pyviz_comms        conda-forge/noarch::pyviz_comms-2.2.1-pyhd8ed1ab_1
#   queuelib           conda-forge/noarch::queuelib-1.6.2-pyhd8ed1ab_0
#   requests-file      conda-forge/noarch::requests-file-1.5.1-pyh9f0ad1d_0
#   s3transfer         conda-forge/noarch::s3transfer-0.6.0-pyhd8ed1ab_0
#   scrapy             conda-forge/linux-64::scrapy-2.7.1-py39hf3d152e_0
#   service_identity   conda-forge/noarch::service_identity-18.1.0-py_0
#   shapely            conda-forge/linux-64::shapely-2.0.0-py39hc9151fd_0
#   smart_open         conda-forge/noarch::smart_open-6.3.0-pyhd8ed1ab_1
#   tabulate           conda-forge/noarch::tabulate-0.9.0-pyhd8ed1ab_1
#   tenacity           conda-forge/noarch::tenacity-8.1.0-pyhd8ed1ab_0
#   tldextract         conda-forge/noarch::tldextract-3.4.0-pyhd8ed1ab_0
#   twisted            pkgs/main/linux-64::twisted-22.2.0-py39h5eee18b_1
#   w3lib              conda-forge/noarch::w3lib-2.1.1-pyhd8ed1ab_0
#   websocket-client   conda-forge/noarch::websocket-client-1.4.2-pyhd8ed1ab_0
#   wget               conda-forge/linux-64::wget-1.20.3-ha56f1ee_1
#   xarray             conda-forge/noarch::xarray-2022.11.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.10.26~ --> conda-forge::ca-certificates-2022.12.7-ha878542_0
#   certifi            pkgs/main/linux-64::certifi-2021.10.8~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   conda              pkgs/main::conda-4.11.0-py39h06a4308_0 --> conda-forge::conda-4.14.0-py39hf3d152e_0
#   libgcc-ng          pkgs/main::libgcc-ng-9.3.0-h5101ec6_17 --> conda-forge::libgcc-ng-12.2.0-h65d4601_19
#   libgomp              pkgs/main::libgomp-9.3.0-h5101ec6_17 --> conda-forge::libgomp-12.2.0-h65d4601_19
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.3.0-hd4cf53~ --> conda-forge::libstdcxx-ng-12.2.0-h46fd767_19
#   openssl              pkgs/main::openssl-1.1.1l-h7f8727e_0 --> conda-forge::openssl-1.1.1s-h0b41bf4_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex          pkgs/main::_openmp_mutex-4.5-1_gnu --> conda-forge::_openmp_mutex-4.5-2_gnu
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2021.11-py39_0 --> custom-py39_1
#
#
#
# Downloading and Extracting Packages
# libidn2-2.3.4        | 157 KB    | ##################################### | 100%
# proj-8.0.1           | 3.1 MB    | ##################################### | 100%
# libunistring-0.9.10  | 1.4 MB    | ##################################### | 100%
# boto3-1.26.55        | 75 KB     | ##################################### | 100%
# hvplot-0.8.2         | 3.0 MB    | ##################################### | 100%
# metpy-1.4.0          | 316 KB    | ##################################### | 100%
# itemadapter-0.7.0    | 14 KB     | ##################################### | 100%
# hyperlink-21.0.0     | 71 KB     | ##################################### | 100%
# requests-file-1.5.1  | 7 KB      | ##################################### | 100%
# scrapy-2.7.1         | 825 KB    | ##################################### | 100%
# conda-4.14.0         | 1011 KB   | ##################################### | 100%
# _anaconda_depends-20 | 67 KB     | ##################################### | 100%
# datashader-0.14.3    | 16.3 MB   | ##################################### | 100%
# tldextract-3.4.0     | 93 KB     | ##################################### | 100%
# botocore-1.29.55     | 5.7 MB    | ##################################### | 100%
# shapely-2.0.0        | 410 KB    | ##################################### | 100%
# nbclassic-0.3.7      | 14 KB     | ##################################### | 100%
# intake-0.6.6         | 114 KB    | ##################################### | 100%
# panel-0.14.2         | 11.8 MB   | ##################################### | 100%
# holoviews-1.15.4     | 3.2 MB    | ##################################### | 100%
# pyhamcrest-2.0.4     | 44 KB     | ##################################### | 100%
# plotly-5.13.0        | 4.2 MB    | ##################################### | 100%
# itemloaders-1.0.6    | 14 KB     | ##################################### | 100%
# pint-0.20.1          | 207 KB    | ##################################### | 100%
# tenacity-8.1.0       | 21 KB     | ##################################### | 100%
# constantly-15.1.0    | 9 KB      | ##################################### | 100%
# pyviz_comms-2.2.1    | 31 KB     | ##################################### | 100%
# anaconda-custom      | 3 KB      | ##################################### | 100%
# parsel-1.7.0         | 17 KB     | ##################################### | 100%
# oniguruma-6.9.8      | 430 KB    | ##################################### | 100%
# jupyter_server-1.13. | 259 KB    | ##################################### | 100%
# incremental-22.10.0  | 18 KB     | ##################################### | 100%
# protego-0.2.1        | 2.6 MB    | ##################################### | 100%
# cssselect-1.2.0      | 21 KB     | ##################################### | 100%
# service_identity-18. | 12 KB     | ##################################### | 100%
# twisted-22.2.0       | 4.1 MB    | ##################################### | 100%
# smart_open-6.3.0     | 46 KB     | ##################################### | 100%
# colorcet-3.0.1       | 1.6 MB    | ##################################### | 100%
# gensim-4.3.0         | 21.8 MB   | ##################################### | 100%
# jq-1.6               | 346 KB    | ##################################### | 100%
# bcrypt-3.2.2         | 45 KB     | ##################################### | 100%
# param-1.12.3         | 78 KB     | ##################################### | 100%
# w3lib-2.1.1          | 24 KB     | ##################################### | 100%
# wget-1.20.3          | 804 KB    | ##################################### | 100%
# cartopy-0.21.1       | 1.5 MB    | ##################################### | 100%
# queuelib-1.6.2       | 14 KB     | ##################################### | 100%
# pydispatcher-2.0.5   | 12 KB     | ##################################### | 100%
# tabulate-0.9.0       | 35 KB     | ##################################### | 100%
# pyproj-3.3.1         | 482 KB    | ##################################### | 100%
# automat-22.10.0      | 27 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /apps/cent7/jupyterhub
#   uid: 871648
#   gid: 132
